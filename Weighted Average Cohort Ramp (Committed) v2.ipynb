# %% [markdown]
# # Imports

# %%
# import necessary python libraries and modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.api as sm
from scipy.stats import pearsonr
import datetime as dt
import seaborn as sns

# %% [markdown]
# # Load and Manipulate Data

# %% [markdown]
# ##### Load Monthly Volume by Cohort Data

# %%
# Load data
df = pd.read_csv('Committed Volume by Cohort by Month.csv', parse_dates=['Month', 'Customer Cohort Month'])
df['Month'] = pd.to_datetime(df['Month'])
#df.set_index('Month', inplace=True)
df = df.sort_values(['Customer Cohort Month', 'Month'])
df
# Out:
#     Customer Cohort Month      Month   Volume
# 499            2018-01-31 2021-03-31   146000
# 602            2018-01-31 2021-04-30   154000
# 964            2018-01-31 2021-05-31   106000
# 51             2018-01-31 2021-06-30   850000
# 575            2018-01-31 2021-07-31  1162000
# ..                    ...        ...      ...
# 914            2023-02-28 2023-05-31   753000
# 169            2023-03-31 2023-03-31    78000
# 550            2023-03-31 2023-04-30    54000
# 712            2023-03-31 2023-05-31   123000
# 226            2023-05-31 2023-05-31    72000
#
# [1005 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1005 entries, 499 to 226
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer Cohort Month  1005 non-null   datetime64[ns]
#  1   Month                  1005 non-null   datetime64[ns]
#  2   Volume                 1005 non-null   int64
# dtypes: datetime64[ns](2), int64(1)
# memory usage: 31.4 KB

# %% [markdown]
# ##### Create Variable for Percent Change in Volume and Remove NaNs (also removed % changes worse than -25% to prevent churn from increasing StDev)

# %%
# make pct change data
df['Volume % Change'] = df.groupby('Customer Cohort Month')['Volume'].pct_change()
df.dropna(inplace=True)
df = df[df['Volume % Change'] > -.25]
df
# Out:
#     Customer Cohort Month      Month   Volume  Volume % Change
# 602            2018-01-31 2021-04-30   154000         0.054795
# 51             2018-01-31 2021-06-30   850000         7.018868
# 575            2018-01-31 2021-07-31  1162000         0.367059
# 112            2018-01-31 2021-08-31  1393000         0.198795
# 996            2018-01-31 2021-09-30  1270000        -0.088299
# ..                    ...        ...      ...              ...
# 164            2022-11-30 2023-05-31   376000         1.785185
# 308            2022-12-31 2023-04-30    73000        35.500000
# 714            2023-02-28 2023-03-31   560000         0.000000
# 914            2023-02-28 2023-05-31   753000         2.376682
# 712            2023-03-31 2023-05-31   123000         1.277778
#
# [810 rows x 4 columns]

# %% [markdown]
# ##### Calculate Mean % Volume Change and Standard Deviation in Volume Change by Cohort

# %%
cohort_std_dev = df.groupby('Customer Cohort Month')['Volume % Change'].std()
cohort_std_dev
# Out:
# Customer Cohort Month
# 2018-01-31      1.746239
# 2018-03-31      0.217977
# 2018-06-30      0.337516
# 2018-07-31      0.411838
# 2018-08-31      0.531375
# 2018-09-30      0.642349
# 2018-10-31      0.575147
# 2018-11-30      0.158598
# 2018-12-31      0.233417
# 2019-01-31      4.960737
# 2019-02-28      2.400939
# 2019-03-31      0.773320
# 2019-04-30      0.845863
# 2019-05-31      0.253470
# 2019-07-31      0.188307
# 2019-08-31      0.310199
# 2019-09-30           NaN
# 2019-10-31      1.876683
# 2019-11-30      0.341242
# 2019-12-31      4.884737
# 2020-02-29      0.441916
# 2020-03-31      0.529220
# 2020-04-30      0.257590
# 2020-05-31           NaN
# 2020-06-30      0.524856
# 2020-07-31      0.866105
# 2020-09-30      0.361644
# 2020-10-31      0.456467
# 2020-11-30      0.314828
# 2020-12-31      0.263664
# 2021-01-31      0.688797
# 2021-02-28      0.761352
# 2021-03-31      4.660689
# 2021-04-30     77.900548
# 2021-05-31      0.838138
# 2021-06-30      1.635490
# 2021-07-31      0.648000
# 2021-08-31      0.954291
# 2021-09-30      0.707107
# 2021-10-31     25.671147
# 2021-11-30    118.823162
# 2021-12-31      0.730809
# 2022-01-31      0.565600
# 2022-02-28      0.510580
# 2022-03-31      1.503888
# 2022-04-30     90.963630
# 2022-05-31      0.809034
# 2022-06-30      0.621492
# 2022-07-31      1.178626
# 2022-08-31      0.483384
# 2022-10-31      0.387798
# 2022-11-30      0.687069
# 2022-12-31           NaN
# 2023-02-28      1.680568
# 2023-03-31           NaN
# Name: Volume % Change, dtype: float64

# %%
cohort_mean = df.groupby('Customer Cohort Month')['Volume % Change'].mean()
cohort_mean
# Out:
# Customer Cohort Month
# 2018-01-31     0.719324
# 2018-03-31    -0.029101
# 2018-06-30     0.126571
# 2018-07-31     0.148232
# 2018-08-31     0.305417
# 2018-09-30     0.188964
# 2018-10-31     0.233868
# 2018-11-30     0.068831
# 2018-12-31     0.079957
# 2019-01-31     3.506495
# 2019-02-28     1.984514
# 2019-03-31     0.291251
# 2019-04-30     0.597401
# 2019-05-31     0.088440
# 2019-07-31     0.099387
# 2019-08-31     0.123862
# 2019-09-30     5.000000
# 2019-10-31     0.502365
# 2019-11-30     0.100295
# 2019-12-31     3.002219
# 2020-02-29     0.209213
# 2020-03-31     0.082711
# 2020-04-30     0.044156
# 2020-05-31     0.000000
# 2020-06-30     0.137736
# 2020-07-31     0.209875
# 2020-09-30     0.265017
# 2020-10-31     0.173214
# 2020-11-30     0.068789
# 2020-12-31     0.080770
# 2021-01-31     0.343354
# 2021-02-28     0.544512
# 2021-03-31     1.135432
# 2021-04-30    19.894586
# 2021-05-31     0.384599
# 2021-06-30     0.595899
# 2021-07-31     0.350846
# 2021-08-31     0.427953
# 2021-09-30     0.500000
# 2021-10-31     7.064306
# 2021-11-30    36.848850
# 2021-12-31     0.779878
# 2022-01-31     0.339086
# 2022-02-28     0.256225
# 2022-03-31     0.556871
# 2022-04-30    29.250527
# 2022-05-31     0.590638
# 2022-06-30     0.338982
# 2022-07-31     0.589306
# 2022-08-31     0.251689
# 2022-10-31     0.280054
# 2022-11-30     0.701755
# 2022-12-31    35.500000
# 2023-02-28     1.188341
# 2023-03-31     1.277778
# Name: Volume % Change, dtype: float64

# %% [markdown]
# #### Join to Create Mean and stDev by Cohort Data

# %%
df0 = pd.merge(cohort_std_dev, cohort_mean, left_on="Customer Cohort Month", right_on='Customer Cohort Month')
df0
# Out:
#                        Volume % Change_x  Volume % Change_y
# Customer Cohort Month
# 2018-01-31                      1.746239           0.719324
# 2018-03-31                      0.217977          -0.029101
# 2018-06-30                      0.337516           0.126571
# 2018-07-31                      0.411838           0.148232
# 2018-08-31                      0.531375           0.305417
# 2018-09-30                      0.642349           0.188964
# 2018-10-31                      0.575147           0.233868
# 2018-11-30                      0.158598           0.068831
# 2018-12-31                      0.233417           0.079957
# 2019-01-31                      4.960737           3.506495
# 2019-02-28                      2.400939           1.984514
# 2019-03-31                      0.773320           0.291251
# 2019-04-30                      0.845863           0.597401
# 2019-05-31                      0.253470           0.088440
# 2019-07-31                      0.188307           0.099387
# 2019-08-31                      0.310199           0.123862
# 2019-09-30                           NaN           5.000000
# 2019-10-31                      1.876683           0.502365
# 2019-11-30                      0.341242           0.100295
# 2019-12-31                      4.884737           3.002219
# 2020-02-29                      0.441916           0.209213
# 2020-03-31                      0.529220           0.082711
# 2020-04-30                      0.257590           0.044156
# 2020-05-31                           NaN           0.000000
# 2020-06-30                      0.524856           0.137736
# 2020-07-31                      0.866105           0.209875
# 2020-09-30                      0.361644           0.265017
# 2020-10-31                      0.456467           0.173214
# 2020-11-30                      0.314828           0.068789
# 2020-12-31                      0.263664           0.080770
# 2021-01-31                      0.688797           0.343354
# 2021-02-28                      0.761352           0.544512
# 2021-03-31                      4.660689           1.135432
# 2021-04-30                     77.900548          19.894586
# 2021-05-31                      0.838138           0.384599
# 2021-06-30                      1.635490           0.595899
# 2021-07-31                      0.648000           0.350846
# 2021-08-31                      0.954291           0.427953
# 2021-09-30                      0.707107           0.500000
# 2021-10-31                     25.671147           7.064306
# 2021-11-30                    118.823162          36.848850
# 2021-12-31                      0.730809           0.779878
# 2022-01-31                      0.565600           0.339086
# 2022-02-28                      0.510580           0.256225
# 2022-03-31                      1.503888           0.556871
# 2022-04-30                     90.963630          29.250527
# 2022-05-31                      0.809034           0.590638
# 2022-06-30                      0.621492           0.338982
# 2022-07-31                      1.178626           0.589306
# 2022-08-31                      0.483384           0.251689
# 2022-10-31                      0.387798           0.280054
# 2022-11-30                      0.687069           0.701755
# 2022-12-31                           NaN          35.500000
# 2023-02-28                      1.680568           1.188341
# 2023-03-31                           NaN           1.277778

# %% [markdown]
# ##### Load Customer Level volume Data and Create % Change in Volume Variable

# %%
df1 = pd.read_csv('Clean Committed Customer Data.csv', parse_dates=['Month', 'Customer Cohort Month'])
df1['Month'] = pd.to_datetime(df1['Month'])
df1 = df1[ ['CUSTOMER_ID-1', 'Month', 'Customer Cohort Month', 'Grand Total']].sort_values(['CUSTOMER_ID-1', 'Month', 'Customer Cohort Month'])
df1
# Out:
#      CUSTOMER_ID-1      Month Customer Cohort Month  Grand Total
# 393      A00000003 2021-06-30            2018-01-31       740000
# 1265     A00000003 2021-07-31            2018-01-31       674000
# 1652     A00000003 2021-08-31            2018-01-31       847000
# 1924     A00000003 2021-09-30            2018-01-31       744000
# 1500     A00000003 2021-10-31            2018-01-31       721000
# ...            ...        ...                   ...          ...
# 1977     A00002412 2023-05-31            2023-03-31        11000
# 1592     A00002429 2023-03-31            2023-03-31         2000
# 1819     A00002429 2023-04-30            2023-03-31         2000
# 428      A00002429 2023-05-31            2023-03-31        13000
# 828      A00002455 2023-05-31            2023-05-31        72000
#
# [2206 rows x 4 columns]

# %%
df1['Volume % Change'] = df1.groupby('CUSTOMER_ID-1')['Grand Total'].pct_change()
df1.dropna(inplace=True)
df1
# Out:
#      CUSTOMER_ID-1      Month Customer Cohort Month  Grand Total  \
# 1265     A00000003 2021-07-31            2018-01-31       674000
# 1652     A00000003 2021-08-31            2018-01-31       847000
# 1924     A00000003 2021-09-30            2018-01-31       744000
# 1500     A00000003 2021-10-31            2018-01-31       721000
# 1629     A00000003 2021-11-30            2018-01-31       761000
# ...            ...        ...                   ...          ...
# 1970     A00002404 2023-05-31            2023-03-31        35000
# 603      A00002412 2023-04-30            2023-03-31        10000
# 1977     A00002412 2023-05-31            2023-03-31        11000
# 1819     A00002429 2023-04-30            2023-03-31         2000
# 428      A00002429 2023-05-31            2023-03-31        13000
#
#       Volume % Change
# 1265        -0.089189
# 1652         0.256677
# 1924        -0.121606
# 1500        -0.030914
# 1629         0.055479
# ...               ...
# 1970         1.500000
# 603         -0.500000
# 1977         0.100000
# 1819         0.000000
# 428          5.500000
#
# [2055 rows x 5 columns]

# %% [markdown]
# ##### Merge stDev and Customer Level Data

# %%
df2 = pd.merge(df1, df0, left_on='Customer Cohort Month', right_on='Customer Cohort Month')
df2
# Out:
#      CUSTOMER_ID-1      Month Customer Cohort Month  Grand Total  \
# 0        A00000003 2021-07-31            2018-01-31       674000
# 1        A00000003 2021-08-31            2018-01-31       847000
# 2        A00000003 2021-09-30            2018-01-31       744000
# 3        A00000003 2021-10-31            2018-01-31       721000
# 4        A00000003 2021-11-30            2018-01-31       761000
# ...            ...        ...                   ...          ...
# 2050     A00002404 2023-05-31            2023-03-31        35000
# 2051     A00002412 2023-04-30            2023-03-31        10000
# 2052     A00002412 2023-05-31            2023-03-31        11000
# 2053     A00002429 2023-04-30            2023-03-31         2000
# 2054     A00002429 2023-05-31            2023-03-31        13000
#
#       Volume % Change  Volume % Change_x  Volume % Change_y
# 0           -0.089189           1.746239           0.719324
# 1            0.256677           1.746239           0.719324
# 2           -0.121606           1.746239           0.719324
# 3           -0.030914           1.746239           0.719324
# 4            0.055479           1.746239           0.719324
# ...               ...                ...                ...
# 2050         1.500000                NaN           1.277778
# 2051        -0.500000                NaN           1.277778
# 2052         0.100000                NaN           1.277778
# 2053         0.000000                NaN           1.277778
# 2054         5.500000                NaN           1.277778
#
# [2055 rows x 7 columns]

# %% [markdown]
# ##### Filter for Where Customer % Change in Volume is Within 1 stDev of Mean Volume Change for the Cohort

# %%
df3 = df2[((df2['Volume % Change_y']-df2['Volume % Change_x'])<=df2['Volume % Change']) & (df2['Volume % Change']<=(df2['Volume % Change_y']+df2['Volume % Change_x']))]
df4 = df3.sort_values(['CUSTOMER_ID-1', 'Month'])
df4
# Out:
#      CUSTOMER_ID-1      Month Customer Cohort Month  Grand Total  \
# 0        A00000003 2021-07-31            2018-01-31       674000
# 1        A00000003 2021-08-31            2018-01-31       847000
# 2        A00000003 2021-09-30            2018-01-31       744000
# 3        A00000003 2021-10-31            2018-01-31       721000
# 4        A00000003 2021-11-30            2018-01-31       761000
# ...            ...        ...                   ...          ...
# 2041     A00001674 2023-03-31            2022-11-30       359000
# 2042     A00001674 2023-04-30            2022-11-30        92000
# 2044     A00001719 2023-03-31            2023-02-28       560000
# 2045     A00001719 2023-04-30            2023-02-28       223000
# 2046     A00001719 2023-05-31            2023-02-28       753000
#
#       Volume % Change  Volume % Change_x  Volume % Change_y
# 0           -0.089189           1.746239           0.719324
# 1            0.256677           1.746239           0.719324
# 2           -0.121606           1.746239           0.719324
# 3           -0.030914           1.746239           0.719324
# 4            0.055479           1.746239           0.719324
# ...               ...                ...                ...
# 2041         0.014124           0.687069           0.701755
# 2042        -0.743733           0.687069           0.701755
# 2044         0.000000           1.680568           1.188341
# 2045        -0.601786           1.680568           1.188341
# 2046         2.376682           1.680568           1.188341
#
# [1837 rows x 7 columns]

# %% [markdown]
# ##### Find the First Month for Each Customer Where % Change in Volume Month-to-Month is Within Bounds (ramp month)

# %%
df5 = df4.groupby(['CUSTOMER_ID-1', 'Customer Cohort Month'])['Month'].min().reset_index()
df5['Ramp_Time_In_Months'] = (df5['Month'].dt.to_period('M') - df5['Customer Cohort Month'].dt.to_period('M')).apply(lambda x: (x.n))
df5
# Out:
#     CUSTOMER_ID-1 Customer Cohort Month      Month  Ramp_Time_In_Months
# 0       A00000003            2018-01-31 2021-07-31                   42
# 1       A00000005            2018-01-31 2022-09-30                   56
# 2       A00000006            2018-01-31 2021-08-31                   43
# 3       A00000031            2018-01-31 2021-04-30                   39
# 4       A00000039            2018-01-31 2021-12-31                   47
# ..            ...                   ...        ...                  ...
# 134     A00001645            2022-10-31 2023-01-31                    3
# 135     A00001648            2022-10-31 2022-12-31                    2
# 136     A00001657            2022-11-30 2023-03-31                    4
# 137     A00001674            2022-11-30 2022-12-31                    1
# 138     A00001719            2023-02-28 2023-03-31                    1
#
# [139 rows x 4 columns]

# %%
df5.drop(columns=['Month'], inplace=True)

# %% [markdown]
# ##### Reload Original Customer Data for Cohort Weighted Averages

# %%
# Reoad in intial data
df1 = pd.read_csv('Clean Committed Customer Data.csv', parse_dates=['Month', 'Customer Cohort Month'])
df1['Month'] = pd.to_datetime(df1['Month'])
df1 = df1 [ ['CUSTOMER_ID-1', 'Month', 'Customer Cohort Month', 'Grand Total']]
df1
# Out:
#      CUSTOMER_ID-1      Month Customer Cohort Month  Grand Total
# 0        A00000340 2022-07-31            2020-06-30      1415000
# 1        A00000261 2022-11-30            2019-08-31       789000
# 2        A00000303 2022-06-30            2020-03-31       444000
# 3        A00001645 2023-03-31            2022-10-31        89000
# 4        A00000421 2021-06-30            2021-05-31       171000
# ...            ...        ...                   ...          ...
# 2201     A00001456 2022-08-31            2021-11-30      7566000
# 2202     A00001477 2023-01-31            2022-01-31         6000
# 2203     A00001420 2022-07-31            2021-08-31       326000
# 2204     A00001416 2022-11-30            2021-06-30      2270000
# 2205     A00000316 2023-05-31            2020-04-30     75215000
#
# [2206 rows x 4 columns]

# %%
df2 = df1.groupby(['CUSTOMER_ID-1', 'Customer Cohort Month'])['Grand Total'].sum()
df2
# Out:
# CUSTOMER_ID-1  Customer Cohort Month
# A00000003      2018-01-31                37286000
# A00000005      2018-01-31               101061000
# A00000006      2018-01-31                 9985000
# A00000031      2018-01-31                   87000
# A00000039      2018-01-31                82161000
#                                           ...
# A00002393      2023-03-31                  111000
# A00002404      2023-03-31                   86000
# A00002412      2023-03-31                   41000
# A00002429      2023-03-31                   17000
# A00002455      2023-05-31                   72000
# Name: Grand Total, Length: 151, dtype: int64

# %% [markdown]
# ##### Join Customer Volume Totals to Ramp Data and Calculate Weighted Average Ramp Time by Cohort

# %%
df3 = pd.merge(df5, df2, left_on=['CUSTOMER_ID-1', 'Customer Cohort Month'], right_on=['CUSTOMER_ID-1', 'Customer Cohort Month'])
df3
# Out:
#     CUSTOMER_ID-1 Customer Cohort Month  Ramp_Time_In_Months  Grand Total
# 0       A00000003            2018-01-31                   42     37286000
# 1       A00000005            2018-01-31                   56    101061000
# 2       A00000006            2018-01-31                   43      9985000
# 3       A00000031            2018-01-31                   39        87000
# 4       A00000039            2018-01-31                   47     82161000
# ..            ...                   ...                  ...          ...
# 134     A00001645            2022-10-31                    3       365000
# 135     A00001648            2022-10-31                    2      3804000
# 136     A00001657            2022-11-30                    4       516000
# 137     A00001674            2022-11-30                    1      1745000
# 138     A00001719            2023-02-28                    1      2096000
#
# [139 rows x 4 columns]

# %%
df4 = df3.groupby('Customer Cohort Month').apply(lambda x: np.average(x['Ramp_Time_In_Months'], weights=x['Grand Total']))
df4 = pd.DataFrame(df4)
df4['Weighted Average Ramp'] = df4[0]
df4.drop(columns=[0], inplace=True)
df4
#df4.to_csv('WeightedAverageRampByCohort.csv)
# Out:
#                        Weighted Average Ramp
# Customer Cohort Month
# 2018-01-31                         51.878036
# 2018-03-31                         58.000000
# 2018-06-30                         36.386486
# 2018-07-31                         36.489613
# 2018-08-31                         36.123785
# 2018-09-30                         31.000000
# 2018-10-31                         31.000000
# 2018-11-30                         29.000000
# 2018-12-31                         28.712548
# 2019-01-31                         39.000000
# 2019-02-28                         48.000000
# 2019-03-31                         36.707295
# 2019-04-30                         32.605707
# 2019-05-31                         23.000000
# 2019-07-31                         21.000000
# 2019-08-31                         21.027566
# 2019-10-31                         20.265106
# 2019-11-30                         23.000000
# 2019-12-31                         35.815313
# 2020-02-29                         14.000000
# 2020-03-31                         13.000000
# 2020-04-30                         12.012944
# 2020-06-30                         13.559148
# 2020-07-31                          9.000000
# 2020-09-30                          7.943285
# 2020-10-31                         19.000000
# 2020-11-30                          5.000000
# 2020-12-31                          4.000000
# 2021-01-31                          3.964253
# 2021-02-28                          2.042947
# 2021-03-31                          2.930066
# 2021-04-30                          6.128414
# 2021-05-31                          4.657163
# 2021-06-30                         10.027971
# 2021-07-31                          1.604900
# 2021-08-31                          2.427122
# 2021-09-30                          5.000000
# 2021-10-31                          1.998587
# 2021-11-30                          3.995639
# 2021-12-31                          1.000000
# 2022-01-31                          1.099052
# 2022-02-28                          2.155302
# 2022-03-31                          1.930943
# 2022-04-30                          1.999780
# 2022-05-31                          4.546282
# 2022-06-30                          1.583394
# 2022-07-31                          1.949012
# 2022-08-31                          1.000000
# 2022-10-31                          2.087551
# 2022-11-30                          1.684653
# 2023-02-28                          1.000000

# %% [markdown]
# ##### Load Cohort Volume Totals Data and Join to Weighted Average Ramp Data

# %%
# Reload data
df = pd.read_csv('Committed Volume by Cohort by Month.csv', parse_dates=['Month', 'Customer Cohort Month'])
df['Month'] = pd.to_datetime(df['Month'])
#df.set_index('Month', inplace=True)
df = df.sort_values('Customer Cohort Month').groupby('Customer Cohort Month').sum()
df
# Out:
#                            Volume
# Customer Cohort Month
# 2018-01-31              375979000
# 2018-03-31                  41000
# 2018-06-30              103313000
# 2018-07-31              421578000
# 2018-08-31               10187000
# 2018-09-30                3882000
# 2018-10-31               52029000
# 2018-11-30               17357000
# 2018-12-31              122518000
# 2019-01-31                1379000
# 2019-02-28               28559000
# 2019-03-31               19535000
# 2019-04-30               64906000
# 2019-05-31              187821000
# 2019-07-31               25604000
# 2019-08-31               11173000
# 2019-09-30                  89000
# 2019-10-31               97878000
# 2019-11-30                7333000
# 2019-12-31                2155000
# 2020-02-29               19331000
# 2020-03-31               18675000
# 2020-04-30             5315044000
# 2020-05-31                   8000
# 2020-06-30               43484000
# 2020-07-31               11765000
# 2020-09-30              100590000
# 2020-10-31              247463000
# 2020-11-30                5670000
# 2020-12-31               95229000
# 2021-01-31               60929000
# 2021-02-28                5891000
# 2021-03-31               97978000
# 2021-04-30                6261000
# 2021-05-31               49207000
# 2021-06-30               36538000
# 2021-07-31                1306000
# 2021-08-31              108243000
# 2021-09-30                   7000
# 2021-10-31              104736000
# 2021-11-30               60531000
# 2021-12-31                 947000
# 2022-01-31               35964000
# 2022-02-28               10618000
# 2022-03-31                4127000
# 2022-04-30              748986000
# 2022-05-31                1318000
# 2022-06-30                2745000
# 2022-07-31                2177000
# 2022-08-31                2442000
# 2022-10-31                4169000
# 2022-11-30                2261000
# 2022-12-31                 120000
# 2023-02-28                2096000
# 2023-03-31                 255000
# 2023-05-31                  72000

# %% [markdown]
# ##### Ignore More Recent Cohorts

# %%
df5 = pd.merge(df, df4, left_index=True, right_index=True)
df5
# Out:
#                            Volume  Weighted Average Ramp
# Customer Cohort Month
# 2018-01-31              375979000              51.878036
# 2018-03-31                  41000              58.000000
# 2018-06-30              103313000              36.386486
# 2018-07-31              421578000              36.489613
# 2018-08-31               10187000              36.123785
# 2018-09-30                3882000              31.000000
# 2018-10-31               52029000              31.000000
# 2018-11-30               17357000              29.000000
# 2018-12-31              122518000              28.712548
# 2019-01-31                1379000              39.000000
# 2019-02-28               28559000              48.000000
# 2019-03-31               19535000              36.707295
# 2019-04-30               64906000              32.605707
# 2019-05-31              187821000              23.000000
# 2019-07-31               25604000              21.000000
# 2019-08-31               11173000              21.027566
# 2019-10-31               97878000              20.265106
# 2019-11-30                7333000              23.000000
# 2019-12-31                2155000              35.815313
# 2020-02-29               19331000              14.000000
# 2020-03-31               18675000              13.000000
# 2020-04-30             5315044000              12.012944
# 2020-06-30               43484000              13.559148
# 2020-07-31               11765000               9.000000
# 2020-09-30              100590000               7.943285
# 2020-10-31              247463000              19.000000
# 2020-11-30                5670000               5.000000
# 2020-12-31               95229000               4.000000
# 2021-01-31               60929000               3.964253
# 2021-02-28                5891000               2.042947
# 2021-03-31               97978000               2.930066
# 2021-04-30                6261000               6.128414
# 2021-05-31               49207000               4.657163
# 2021-06-30               36538000              10.027971
# 2021-07-31                1306000               1.604900
# 2021-08-31              108243000               2.427122
# 2021-09-30                   7000               5.000000
# 2021-10-31              104736000               1.998587
# 2021-11-30               60531000               3.995639
# 2021-12-31                 947000               1.000000
# 2022-01-31               35964000               1.099052
# 2022-02-28               10618000               2.155302
# 2022-03-31                4127000               1.930943
# 2022-04-30              748986000               1.999780
# 2022-05-31                1318000               4.546282
# 2022-06-30                2745000               1.583394
# 2022-07-31                2177000               1.949012
# 2022-08-31                2442000               1.000000
# 2022-10-31                4169000               2.087551
# 2022-11-30                2261000               1.684653
# 2023-02-28                2096000               1.000000

# %% [markdown]
# ##### Export to .csv file

# %%
#df5.to_csv('Weighted Average Ramp Time (Committed).csv', header=True)

# %% [markdown]
# ##### Calculate Weighted Average of Weighted Averages (just a sense check; not as accurate as replicating the analysis at the cohort, not customer level, and weighting aggregate cohort ramp)

# %%
totalVol = df5['Volume'].sum()
df5['Weight'] = df5['Volume'] / totalVol
weightedAverageRamp = (df5['Weighted Average Ramp'] * df5['Weight']).sum()
weightedAverageRamp
# Out:
# 14.93292861829684
